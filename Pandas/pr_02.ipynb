# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('deliveries.csv')

# %%
data
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
data.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
runs = data.groupby('batsman')

# %%
runs

# %%
runs.get_group("V Kohli")
# Out:
#         match_id  inning                 batting_team         bowling_team  \
# 2590          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2591          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2593          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2594          12       1  Royal Challengers Bangalore       Mumbai Indians
# 2597          12       1  Royal Challengers Bangalore       Mumbai Indians
# ...          ...     ...                          ...                  ...
# 177522     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177523     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177524     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177525     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
# 177527     11345       2  Royal Challengers Bangalore  Sunrisers Hyderabad
#
# ...

# %%
runs.get_group("V Kohli").shape
# Out:
# (4211, 21)

# %%
runs['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# batsman
# V Kohli      5434
# SK Raina     5415
# RG Sharma    4914
# DA Warner    4741
# S Dhawan     4632
# Name: batsman_runs, dtype: int64

# %%
runs['batsman_runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
mask = data['batsman_runs']==4
print(mask)
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 179073    False
# 179074    False
# 179075    False
# 179076    False
# 179077    False
# Name: batsman_runs, Length: 179078, dtype: bool

# %%
new_delivery = data[mask]

# %%
new_delivery.shape
# Out:
# (20392, 21)

# %%
new_delivery.shape[0]
# Out:
# 20392

# %%
new_delivery.shape
# Out:
# (20392, 21)

# %%
mask = data['batsman_runs']==4
print(mask)
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 179073    False
# 179074    False
# 179075    False
# 179076    False
# 179077    False
# Name: batsman_runs, Length: 179078, dtype: bool

# %%
new_delivery = data[mask]

# %%
new_delivery.shape
# Out:
# (20392, 21)

# %%
new_delivery.shape[0]
# Out:
# 20392

# %%
new_delivery.groupby('batsman')

# %%
new_delivery.groupby('batsman')['batsman_runs'].count()
# Out:
# batsman
# A Ashish Reddy     16
# A Chopra            7
# A Choudhary         1
# A Flintoff          5
# A Hales            13
#                  ...
# YK Pathan         264
# YV Takawale        26
# Yashpal Singh       5
# Yuvraj Singh      218
# Z Khan             11
# Name: batsman_runs, Length: 410, dtype: int64

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False)
# Out:
# batsman
# S Dhawan       526
# SK Raina       495
# G Gambhir      492
# V Kohli        482
# DA Warner      459
#               ...
# AN Ghosh         1
# AG Murtaza       1
# UA Birla         1
# Umar Gul         1
# A Choudhary      1
# Name: batsman_runs, Length: 410, dtype: int64

# %%
new_delivery.groupby('batsman')['batsman_runs'].count().sort_values(ascending=False).head(5)
# Out:
# batsman
# S Dhawan     526
# SK Raina     495
# G Gambhir    492
# V Kohli      482
# DA Warner    459
# Name: batsman_runs, dtype: int64

# %%
vk= data[data['batsman']== 'V Kohli']

# %%
vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(3)
# Out:
# bowling_team
# Delhi Daredevils         763
# Chennai Super Kings      749
# Kolkata Knight Riders    675
# Name: batsman_runs, dtype: int64

# %%
def run_scored(batsman_name):
    vk= data[data['batsman']== batsman_name]
    return vk.groupby('bowling_team')['batsman_runs'].sum().sort_values(ascending=False).head(3)

# %%
run_scored('DA Warner')
# Out:
# bowling_team
# Kolkata Knight Riders          835
# Kings XI Punjab                833
# Royal Challengers Bangalore    670
# Name: batsman_runs, dtype: int64

# %%
# The isin() function
1  # isin()
2  # Find the most destructive death over batsman in the history of IPL
3  # Strike Rate=(Number of runs/Number of balls)*100
4  # Min batsman 200 balls in over 16-20

# %%
# data['over']>15
# [data[data['over']>15]]
death_over = data[data['over']>15]

# %%
# data.groupby('batsman')['batsman_runs'].count()

# death_over.groupby('batsman')['batsman_runs'].count()

death_over.groupby('batsman')['batsman_runs'].count()>200
# Out:
# batsman
# A Ashish Reddy    False
# A Chandila        False
# A Chopra          False
# A Choudhary       False
# A Dananjaya       False
#                   ...
# YS Chahal         False
# YV Takawale       False
# Yashpal Singh     False
# Yuvraj Singh       True
# Z Khan            False
# Name: batsman_runs, Length: 465, dtype: bool

# %%
all_batsman = death_over.groupby('batsman')['batsman_runs'].count()
all_batsman
# Out:
# batsman
# A Ashish Reddy    148
# A Chandila          7
# A Chopra            2
# A Choudhary        20
# A Dananjaya         5
#                  ...
# YS Chahal          35
# YV Takawale        13
# Yashpal Singh      13
# Yuvraj Singh      535
# Z Khan            109
# Name: batsman_runs, Length: 465, dtype: int64

# %%
x = all_batsman>20
all_batsman[x]
# Out:
# batsman
# A Ashish Reddy     148
# A Kumble            44
# A Mishra           247
# A Nehra             63
# A Symonds          197
#                   ...
# Y Venugopal Rao    260
# YK Pathan          732
# YS Chahal           35
# Yuvraj Singh       535
# Z Khan             109
# Name: batsman_runs, Length: 277, dtype: int64

# %%
all_batsman[x].shape
# Out:
# (277,)

# %%
all_batsman[x].index
# Out:
# Index(['A Ashish Reddy', 'A Kumble', 'A Mishra', 'A Nehra', 'A Symonds',
#        'AA Bilakhia', 'AA Jhunjhunwala', 'AB Agarkar', 'AB Dinda',
#        'AB McDonald',
#        ...
#        'WD Parnell', 'WP Saha', 'WPUJC Vaas', 'Washington Sundar', 'Y Nagar',
#        'Y Venugopal Rao', 'YK Pathan', 'YS Chahal', 'Yuvraj Singh', 'Z Khan'],
#       dtype='object', name='batsman', length=277)

# %%
batmans_list = all_batsman[x].index.tolist()

# %%
batmans_list
# Out:
# ['A Ashish Reddy',
#  'A Kumble',
#  'A Mishra',
#  'A Nehra',
#  'A Symonds',
#  'AA Bilakhia',
#  'AA Jhunjhunwala',
#  'AB Agarkar',
#  'AB Dinda',
#  'AB McDonald',
#  'AB de Villiers',
#  'AC Gilchrist',
#  'AC Voges',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AJ Finch',
#  'AJ Tye',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AN Ahmed',
#  'AP Dole',
#  'AP Tare',
#  'AR Patel',
#  'AS Rajpoot',
#  'AS Raut',
#  'AS Yadav',
#  'AT Rayudu',
#  'Ankit Sharma',
#  'Anureet Singh',
#  'Azhar Mahmood',
#  'B Akhil',
#  'B Chipli',
#  'B Kumar',
#  'B Lee',
#  'B Sumanth',
#  'BA Stokes',
#  'BB McCullum',
#  'BB Samantray',
#  'BCJ Cutting',
#  'BJ Hodge',
#  'BJ Rohrer',
#  'Basil Thampi',
#  'Bipul Sharma',
#  'C Ingram',
#  'C de Grandhomme',
#  'CA Lynn',
#  'CA Pujara',
#  'CH Gayle',
#  'CH Morris',
#  'CJ Anderson',
#  'CJ Ferguson',
#  'CK Kapugedera',
#  'CL White',
#  'CM Gautam',
#  'CR Brathwaite',
#  'CR Woakes',
#  'D Wiese',
# ...

# %%
# data['batsman']
data['batsman'].isin(batmans_list)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 179073    True
# 179074    True
# 179075    True
# 179076    True
# 179077    True
# Name: batsman, Length: 179078, dtype: bool

# %%
data[data['batsman'].isin(batmans_list)]
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
data[data['batsman'].isin(batmans_list)].shape
# Out:
# (168969, 21)

# %%
final = data[data['batsman'].isin(batmans_list)]

# %%
runs=final.groupby('batsman')['batsman_runs'].sum()

# %%
balls=final.groupby('batsman')['batsman_runs'].count()

# %%
sr = (runs/balls)*100

# %%
sr
# Out:
# batsman
# A Ashish Reddy     142.857143
# A Kumble            71.428571
# A Mishra            89.756098
# A Nehra             65.079365
# A Symonds          124.711908
#                       ...
# Y Venugopal Rao    113.872832
# YK Pathan          138.860326
# YS Chahal           44.897959
# Yuvraj Singh       125.283190
# Z Khan              82.978723
# Name: batsman_runs, Length: 277, dtype: float64

# %%
# The merge function
