# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '2.3.3'

# %%
data = pd.read_csv('matches.csv')

# %%
print(data)
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
# data.head()  #top five level data show (data preview)
data.head(3)  #top 3 level data show (data preview)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.tail()  #bottom five level data show (data preview)
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
data.tail(3)
# Out:
#         id  season           city      date                team1  \
# 753  11413    2019  Visakhapatnam  08/05/19  Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19       Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %%
data.shape
# Out:
# (756, 18)

# %%
data.shape[1]
# Out:
# 18

# %%
data.shape[0]
# Out:
# 756

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
# pandas ko string ko object manta hy

# %%
data.describe() #numerical value pr kam kry ka
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['winner']
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 751                 Mumbai Indians
# 752                 Mumbai Indians
# 753                 Delhi Capitals
# 754            Chennai Super Kings
# 755                 Mumbai Indians
# Name: winner, Length: 756, dtype: object

# %%
type(data['winner'])
# Out:
# pandas.core.series.Series

# %%
#!Series -> index(self generate ya khud sy be nikalajata hy) and values

# %%
data[['team1','team2','winner']]
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(data[['team1','team2','winner']])
# Out:
# pandas.core.frame.DataFrame

# %%
data[['team1','team2','winner']].shape
# Out:
# (756, 3)

# %%
# iloc -> first row data show
data.iloc[0]
# Out:
# id                                                         1
# season                                                  2017
# city                                               Hyderabad
# date                                              2017-04-05
# team1                                    Sunrisers Hyderabad
# team2                            Royal Challengers Bangalore
# toss_winner                      Royal Challengers Bangalore
# toss_decision                                          field
# result                                                normal
# dl_applied                                                 0
# winner                                   Sunrisers Hyderabad
# win_by_runs                                               35
# win_by_wickets                                             0
# player_of_match                                 Yuvraj Singh
# venue              Rajiv Gandhi International Stadium, Uppal
# ...

# %%
data.iloc[0:3]  #first 3 rows data show
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06       Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
# fancing indexing iloc ma kam kry ka

# %%
data.iloc[[1,5,7]]
# Out:
#    id  season       city        date                        team1  \
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
#
#                     team2                  toss_winner toss_decision  result  \
# 1  Rising Pune Supergiant       Rising Pune Supergiant         field  normal
# 5     Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# 7         Kings XI Punjab  Royal Challengers Bangalore           bat  normal
#
#    dl_applied                  winner  win_by_runs  win_by_wickets  \
# 1           0  Rising Pune Supergiant            0               7
# 5           0     Sunrisers Hyderabad            0               9
# 7           0         Kings XI Punjab            0               8
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
data.iloc[:,[4,5,10]] #facinf indexing support
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 751        Kolkata Knight Riders               Mumbai Indians
# 752          Chennai Super Kings               Mumbai Indians
# 753          Sunrisers Hyderabad               Delhi Capitals
# 754               Delhi Capitals          Chennai Super Kings
# 755               Mumbai Indians          Chennai Super Kings
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
#  mask

# %%
type(data['city'] == 'Hyderabad')
# Out:
# pandas.core.series.Series

# %%
data['city'] == 'Hyderabad'
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 751    False
# 752    False
# 753    False
# 754    False
# 755     True
# Name: city, Length: 756, dtype: bool

# %%
msk = data['city'] == 'Hyderabad'

# %%
data[msk]
# Out:
#         id  season       city        date                  team1  \
# 0        1    2017  Hyderabad  2017-04-05    Sunrisers Hyderabad
# 5        6    2017  Hyderabad  2017-04-09          Gujarat Lions
# 18      19    2017  Hyderabad  2017-04-17    Sunrisers Hyderabad
# 20      21    2017  Hyderabad  2017-04-19    Sunrisers Hyderabad
# 35      36    2017  Hyderabad  2017-04-30    Sunrisers Hyderabad
# ..     ...     ...        ...         ...                    ...
# 725  11321    2019  Hyderabad    14/04/19         Delhi Capitals
# 728  11324    2019  Hyderabad    17/04/19    Chennai Super Kings
# 733  11329    2019  Hyderabad    21/04/19  Kolkata Knight Riders
# 743  11339    2019  Hyderabad    29/04/19    Sunrisers Hyderabad
# 755  11415    2019  Hyderabad    12/05/19         Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
data[msk].shape
# Out:
# (64, 18)

# %%
data[msk].shape[0]
# Out:
# 64

# %%
def get_city_match_count(city_name):
    msk = data['city'] == city_name
    return data[msk].shape[0]

get_city_match_count('Indore')
# Out:
# 9

# %%
mask1 = data['city'] == "Hyderabad"
mask2 = data['date'] > '2017-01-01'
data[mask1 & mask2]
# data[mask1 & mask2].shape
# Out:
#         id  season       city        date                   team1  \
# 0        1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 5        6    2017  Hyderabad  2017-04-09           Gujarat Lions
# 18      19    2017  Hyderabad  2017-04-17     Sunrisers Hyderabad
# 20      21    2017  Hyderabad  2017-04-19     Sunrisers Hyderabad
# 35      36    2017  Hyderabad  2017-04-30     Sunrisers Hyderabad
# 42      43    2017  Hyderabad  2017-05-06  Rising Pune Supergiant
# 46      47    2017  Hyderabad  2017-05-08          Mumbai Indians
# 58      59    2017  Hyderabad  2017-05-21          Mumbai Indians
# 655   7913    2018  Hyderabad    22/04/18     Chennai Super Kings
# 660   7918    2018  Hyderabad    26/04/18     Sunrisers Hyderabad
# 703  11144    2019  Hyderabad    29/03/19        Rajasthan Royals
# 706  11147    2019  Hyderabad    31/03/19     Sunrisers Hyderabad
# 733  11329    2019  Hyderabad    21/04/19   Kolkata Knight Riders
# ...

# %%
# value_count()

# %%
data['winner'].value_counts()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
# The Plot function

# %%
import matplotlib.pyplot as plt

# %%
type(data['winner'].value_counts())
# Out:
# pandas.core.series.Series

# %%
data['winner'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>

# %%
data['winner'].value_counts().head().plot(kind='barh')
# Out:
# <Axes: ylabel='winner'>

# %%
data['toss_decision'].value_counts()
# Out:
# toss_decision
# field    463
# bat      293
# Name: count, dtype: int64

# %%
data['toss_decision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data['win_by_runs'].value_counts()
# Out:
# win_by_runs
# 0      419
# 14      13
# 10      11
# 4       11
# 1       10
#       ...
# 62       1
# 144      1
# 64       1
# 102      1
# 118      1
# Name: count, Length: 89, dtype: int64

# %%
data['win_by_runs'].value_counts().plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Series Operations

# %%
myseries = data['winner'].value_counts()

# %%
myseries
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
myseries.index
# Out:
# Index(['Mumbai Indians', 'Chennai Super Kings', 'Kolkata Knight Riders',
#        'Royal Challengers Bangalore', 'Kings XI Punjab', 'Rajasthan Royals',
#        'Delhi Daredevils', 'Sunrisers Hyderabad', 'Deccan Chargers',
#        'Gujarat Lions', 'Pune Warriors', 'Rising Pune Supergiant',
#        'Delhi Capitals', 'Kochi Tuskers Kerala', 'Rising Pune Supergiants'],
#       dtype='object', name='winner')

# %%
myseries.values
# Out:
# array([109, 100,  92,  84,  82,  75,  67,  58,  29,  13,  12,  10,  10,
#          6,   5])

# %%
myseries.head()
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Name: count, dtype: int64

# %%
myseries.tail()
# Out:
# winner
# Pune Warriors              12
# Rising Pune Supergiant     10
# Delhi Capitals             10
# Kochi Tuskers Kerala        6
# Rising Pune Supergiants     5
# Name: count, dtype: int64

# %%
print(myseries['Royal Challengers Bangalore'])
# Out:
# 84

# %%
myseries['Royal Challengers Bangalore']
# Out:
# np.int64(84)

# %%
data['team2'].value_counts() + data['team1'].value_counts()

# agr same index ma ho ka tou is ma addiotn,multiplication,divison etc use kr sakty hy
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# Name: count, dtype: int64

# %%
# The sort_values() method
(data['team1'].value_counts() + data['team2'].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Delhi Capitals                  16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
data.sort_values('city') #not a perment data change hy
# Out:
#       id  season       city        date                        team1  \
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values('city',ascending=False)  # bydefault ascending true  hota hy
# Out:
#         id  season           city        date                        team1  \
# 612    613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 530    531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 628    629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 615    616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# ..     ...     ...            ...         ...                          ...
# 466    467    2014            NaN  2014-04-23          Chennai Super Kings
# 468    469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469    470    2014            NaN  2014-04-25               Mumbai Indians
# 474    475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476    477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
# ...

# %%
data.sort_values('city',ascending=False,inplace=True)  # bydefault inplace false  hota hy inplace sy perment sort hota hy

# %%
data
# Out:
#         id  season           city        date                        team1  \
# 612    613    2016  Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 530    531    2015  Visakhapatnam  2015-04-18             Delhi Daredevils
# 628    629    2016  Visakhapatnam  2016-05-21              Kings XI Punjab
# 615    616    2016  Visakhapatnam  2016-05-10          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# ..     ...     ...            ...         ...                          ...
# 466    467    2014            NaN  2014-04-23          Chennai Super Kings
# 468    469    2014            NaN  2014-04-25          Sunrisers Hyderabad
# 469    470    2014            NaN  2014-04-25               Mumbai Indians
# 474    475    2014            NaN  2014-04-28  Royal Challengers Bangalore
# 476    477    2014            NaN  2014-04-30          Sunrisers Hyderabad
#
# ...

# %%
data.sort_values(['city','date']) # multiple column pr sort krna hy tou list ma dy dyty hy
# Out:
#       id  season       city        date                        team1  \
# 457  458    2014  Abu Dhabi  2014-04-16        Kolkata Knight Riders
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# 460  461    2014  Abu Dhabi  2014-04-18          Sunrisers Hyderabad
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# ..   ...     ...        ...         ...                          ...
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 474  475    2014        NaN  2014-04-28  Royal Challengers Bangalore
# 476  477    2014        NaN  2014-04-30          Sunrisers Hyderabad
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.sort_values(['city','date'],ascending=[True,False]) # multiple column pr sort krna hy tou list ma dy dyty hy
# Out:
#       id  season       city        date                        team1  \
# 475  476    2014  Abu Dhabi  2014-04-29             Rajasthan Royals
# 471  472    2014  Abu Dhabi  2014-04-26              Kings XI Punjab
# 470  471    2014  Abu Dhabi  2014-04-26  Royal Challengers Bangalore
# 464  465    2014  Abu Dhabi  2014-04-21          Chennai Super Kings
# 459  460    2014  Abu Dhabi  2014-04-18          Chennai Super Kings
# ..   ...     ...        ...         ...                          ...
# 468  469    2014        NaN  2014-04-25          Sunrisers Hyderabad
# 469  470    2014        NaN  2014-04-25               Mumbai Indians
# 466  467    2014        NaN  2014-04-23          Chennai Super Kings
# 461  462    2014        NaN  2014-04-19               Mumbai Indians
# 462  463    2014        NaN  2014-04-19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
# The drop_duplicates() method

# %%
data.shape
# Out:
# (756, 18)

# %%
data.drop_duplicates(subset=['city'])
# Out:
#         id  season            city        date                        team1  \
# 612    613    2016   Visakhapatnam  2016-05-08          Sunrisers Hyderabad
# 458    459    2014         Sharjah  2014-04-17             Delhi Daredevils
# 440    441    2013          Ranchi  2013-05-12  Royal Challengers Bangalore
# 606    607    2016          Rajkot  2016-05-03                Gujarat Lions
# 560    561    2015          Raipur  2015-05-09          Sunrisers Hyderabad
# 357    358    2012            Pune  2012-05-08                Pune Warriors
# 121    122    2009  Port Elizabeth  2009-04-20          Chennai Super Kings
# 215    216    2010          Nagpur  2010-04-10          Chennai Super Kings
# 36      37    2017          Mumbai  2017-05-01  Royal Challengers Bangalore
# 651   7909    2018          Mohali    19/04/18              Kings XI Punjab
# 554    555    2015         Kolkata  2015-05-04        Kolkata Knight Riders
# ...

# %%
data.drop_duplicates(subset=['city']).shape
# Out:
# (33, 18)

# %%
# data.drop_duplicates(subset=['city'],inplace=True) # input argument sy perment delete ho jata hy

# %%
data.drop_duplicates(subset=['city','season'])
# Out:
#         id  season           city        date                team1  \
# 612    613    2016  Visakhapatnam  2016-05-08  Sunrisers Hyderabad
# 530    531    2015  Visakhapatnam  2015-04-18     Delhi Daredevils
# 754  11414    2019  Visakhapatnam    10/05/19       Delhi Capitals
# 312    313    2012  Visakhapatnam  2012-04-07  Chennai Super Kings
# 458    459    2014        Sharjah  2014-04-17     Delhi Daredevils
# ..     ...     ...            ...         ...                  ...
# 481    482    2014      Ahmedabad  2014-05-05     Rajasthan Royals
# 186    187    2010      Ahmedabad  2010-03-20     Rajasthan Royals
# 532    533    2015      Ahmedabad  2015-04-19  Chennai Super Kings
# 475    476    2014      Abu Dhabi  2014-04-29     Rajasthan Royals
# 461    462    2014            NaN  2014-04-19       Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 612               Mumbai Indians               Mumbai Indians         field
# ...

# %%
data.drop_duplicates(subset=['city','season']).shape
# Out:
# (126, 18)

# %%
data.drop_duplicates(subset='season',keep='last')
# Out:
#         id  season          city        date                        team1  \
# 164    165    2009  Bloemfontein  2009-05-17             Delhi Daredevils
# 712  11153    2019     Bengaluru    05/04/19  Royal Challengers Bangalore
# 654   7912    2018     Bengaluru    21/04/18             Delhi Daredevils
# 29      30    2017     Bangalore  2017-04-27  Royal Challengers Bangalore
# 241    242    2011     Bangalore  2011-04-12  Royal Challengers Bangalore
# 431    432    2013     Bangalore  2013-04-09          Sunrisers Hyderabad
# 366    367    2012     Bangalore  2012-05-14  Royal Challengers Bangalore
# 605    606    2016     Bangalore  2016-05-02  Royal Challengers Bangalore
# 69      70    2008     Bangalore  2008-04-26  Royal Challengers Bangalore
# 179    180    2010     Ahmedabad  2010-03-15             Rajasthan Royals
# 525    526    2015     Ahmedabad  2015-04-14               Mumbai Indians
# 476    477    2014           NaN  2014-04-30          Sunrisers Hyderabad
#
# ...

# %%
data.drop_duplicates('season',keep='last')[['season','city']].sort_values('season',ascending=True)
# Out:
#      season          city
# 69     2008     Bangalore
# 164    2009  Bloemfontein
# 179    2010     Ahmedabad
# 241    2011     Bangalore
# 366    2012     Bangalore
# 431    2013     Bangalore
# 476    2014           NaN
# 525    2015     Ahmedabad
# 605    2016     Bangalore
# 29     2017     Bangalore
# 654    2018     Bengaluru
# 712    2019     Bengaluru

# %%
# The Groupby() function

# %%
company = pd.read_csv("fortune500.csv", encoding="latin1")

# %%
company.head(2)
# Out:
#    Rank        Company Name Number of Employees  Previous Rank   Revenues  \
# 0     1             Walmart           23,00,000            1.0  $4,85,873
# 1     2  Berkshire Hathaway            3,67,700            4.0  $2,23,604
#
#   Revenue Change    Profits Profit Change     Assets Market Value
# 0           0.8%  $13,643.0         -7.2%  $1,98,825    $2,18,619
# 1           6.1%  $24,074.0          0.0%  $6,20,854    $4,11,035

# %%
# Group by in Pandas
group_by = company.groupby("Assets")

# %%
group_by

# %%
len('Rank')
# Out:
# 4

# %%
group_by.size()
# Out:
# Assets
# $1,00,245    1
# $1,04,658    1
# $1,08,610    1
# $1,09,697    1
# $1,12,180    1
#             ..
# $90,207      1
# $92,033      1
# $92,308      1
# $94,462      1
# $95,377      1
# Length: 498, dtype: int64

# %%
group_by.size().sort_values(ascending=False)
# Out:
# Assets
# $5,560       2
# $6,908       2
# $1,08,610    1
# $88,561      1
# $89,706      1
#             ..
# $1,25,592    1
# $1,25,968    1
# $1,27,136    1
# $1,29,819    1
# $95,377      1
# Length: 498, dtype: int64

# %%
group_by.first()
# Out:
#            Rank                 Company Name Number of Employees  \
# Assets
# $1,00,245    99               Travelers Cos.              30,900
# $1,04,658   329           Genworth Financial               3,400
# $1,08,610    84                     Allstate              43,275
# $1,09,697   145                     Southern              32,015
# $1,12,180    81                       Oracle            1,36,000
# ...         ...                          ...                 ...
# $90,207     185          Synchrony Financial              15,000
# $92,033      52                       Disney            1,95,000
# $92,308     277  Discover Financial Services              15,549
# $94,462       7                   CVS Health            2,04,000
# $95,377      69                        Merck              68,000
#
#            Previous Rank   Revenues Revenue Change   Profits Profit Change  \
# Assets
# $1,00,245          105.0    $27,625           3.1%  $3,014.0        -12.4%
# ...

# %%
group_by.last()
# Out:
#            Rank                 Company Name Number of Employees  \
# Assets
# $1,00,245    99               Travelers Cos.              30,900
# $1,04,658   329           Genworth Financial               3,400
# $1,08,610    84                     Allstate              43,275
# $1,09,697   145                     Southern              32,015
# $1,12,180    81                       Oracle            1,36,000
# ...         ...                          ...                 ...
# $90,207     185          Synchrony Financial              15,000
# $92,033      52                       Disney            1,95,000
# $92,308     277  Discover Financial Services              15,549
# $94,462       7                   CVS Health            2,04,000
# $95,377      69                        Merck              68,000
#
#            Previous Rank   Revenues Revenue Change   Profits Profit Change  \
# Assets
# $1,00,245          105.0    $27,625           3.1%  $3,014.0        -12.4%
# ...

# %%
group_by.groups
# Out:
# {'$1,00,245': [98], '$1,04,658': [328], '$1,08,610': [83], '$1,09,697': [144], '$1,12,180': [80], '$1,13,327': [46], '$1,14,904': [88], '$1,17,470': [31], '$1,18,206': [40], '$1,20,480': [105], '$1,21,652': [59], '$1,22,810': [5], '$1,23,449': [454], '$1,25,592': [74], '$1,25,968': [435], '$1,27,136': [35], '$1,29,819': [125], '$1,32,761': [120], '$1,36,453': [478], '$1,39,821': [238], '$1,41,208': [34], '$1,42,177': [388], '$1,43,298': [301], '$1,47,290': [101], '$1,49,067': [95], '$1,49,520': [450], '$1,497': [246], '$1,58,893': [85], '$1,608': [494], '$1,63,728': [285], '$1,660': [469], '$1,67,497': [26], '$1,71,615': [53], '$1,778': [492], '$1,80,500': [30], '$1,93,694': [27], '$1,930': [349], '$1,97,790': [67], '$1,98,825': [0], '$10,037': [467], '$10,060': [128], '$10,100': [365], '$10,116': [391], '$10,178': [352], '$10,231': [310], '$10,318': [275], '$10,323': [151], '$10,582': [191], '$10,780': [213], '$10,847': [456], '$10,903': [393], '$11,068': [334], '$11,240': [107], '$
# ...

# %%
company.columns
# Out:
# Index(['Rank', 'Company Name', 'Number of Employees', 'Previous Rank',
#        'Revenues', 'Revenue Change', 'Profits', 'Profit Change', 'Assets',
#        'Market Value'],
#       dtype='object')

# %%
group_by.sum()
# Out:
#            Rank                 Company Name Number of Employees  \
# Assets
# $1,00,245    99               Travelers Cos.              30,900
# $1,04,658   329           Genworth Financial               3,400
# $1,08,610    84                     Allstate              43,275
# $1,09,697   145                     Southern              32,015
# $1,12,180    81                       Oracle            1,36,000
# ...         ...                          ...                 ...
# $90,207     185          Synchrony Financial              15,000
# $92,033      52                       Disney            1,95,000
# $92,308     277  Discover Financial Services              15,549
# $94,462       7                   CVS Health            2,04,000
# $95,377      69                        Merck              68,000
#
#            Previous Rank   Revenues Revenue Change   Profits Profit Change  \
# Assets
# $1,00,245          105.0    $27,625           3.1%  $3,014.0        -12.4%
# ...

# %%
group_by.get_group('Revenues')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 group_by.get_group('Revenues')
#
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1116, in BaseGroupBy.get_group(self, name, obj)
#    1114 inds = self._get_index(name)
#    1115 if not len(inds):
# -> 1116     raise KeyError(name)
#    1118 if obj is None:
#    1119     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'Revenues'

# %%
group_by.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
# ...

# %%
group_by['Revenues']

# %%
group_by['Revenues'].mean().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Bilal\miniconda3\Lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
# ...
